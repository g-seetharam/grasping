# %%
# Training Code

# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import os

# Define dataset paths
train_dir = r'C:\Users\seeth\Desktop\Final Year Project\Project\dataset\train'  # Update the actual path
val_dir = r'C:\Users\seeth\Desktop\Final Year Project\Project\dataset\val'      # Update the actual path

# Check if paths exist
if not os.path.exists(train_dir) or not os.path.exists(val_dir):
    print("Dataset paths do not exist. Please check the paths!")

# Image data generators
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1.0/255.0)

# Data generators
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

# Build a CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')  # Two classes: cylinder, hexagon
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()

# Train the model
history = model.fit(
    train_generator,
    epochs=25,  # Adjust as needed
    validation_data=val_generator
)

# Save the model
model.save('shape_classifier_model.h5')
print("Model saved successfully!")
# Out:
# Found 269 images belonging to 2 classes.
# Found 88 images belonging to 2 classes.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 3,304,898
# Trainable params: 3,304,898
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 9/9 [==============================] - 13s 1s/step - loss: 0.9480 - accuracy: 0.5093 - val_loss: 0.6827 - val_accuracy: 0.5455
# Epoch 2/25
# 9/9 [==============================] - 7s 737ms/step - loss: 0.6554 - accuracy: 0.5502 - val_loss: 0.7501 - val_accuracy: 0.5114
# Epoch 3/25
# 9/9 [==============================] - 7s 712ms/step - loss: 0.6442 - accuracy: 0.5948 - val_loss: 0.7528 - val_accuracy: 0.5227
# Epoch 4/25
# 9/9 [==============================] - 6s 708ms/step - loss: 0.6520 - accuracy: 0.5725 - val_loss: 0.7800 - val_accuracy: 0.5341
# Epoch 5/25
# 9/9 [==============================] - 6s 704ms/step - loss: 0.6164 - accuracy: 0.6208 - val_loss: 0.7621 - val_accuracy: 0.5227
# Epoch 6/25
# 9/9 [==============================] - 7s 753ms/step - loss: 0.6477 - accuracy: 0.5911 - val_loss: 0.7322 - val_accuracy: 0.5455
# Epoch 7/25
# 9/9 [==============================] - 7s 772ms/step - loss: 0.6019 - accuracy: 0.6357 - val_loss: 0.8056 - val_accuracy: 0.5114
# Epoch 8/25
# 9/9 [==============================] - 7s 689ms/step - loss: 0.5904 - accuracy: 0.6617 - val_loss: 1.1155 - val_accuracy: 0.5455
# Epoch 9/25
# 9/9 [==============================] - 6s 706ms/step - loss: 0.5984 - accuracy: 0.6357 - val_loss: 0.8310 - val_accuracy: 0.5568
# Epoch 10/25
# 9/9 [==============================] - 7s 723ms/step - loss: 0.6213 - accuracy: 0.6245 - val_loss: 0.8105 - val_accuracy: 0.5000
# Epoch 11/25
# 9/9 [==============================] - 7s 732ms/step - loss: 0.5755 - accuracy: 0.6952 - val_loss: 0.8130 - val_accuracy: 0.5909
# Epoch 12/25
# 9/9 [==============================] - 7s 733ms/step - loss: 0.5674 - accuracy: 0.7175 - val_loss: 0.9601 - val_accuracy: 0.5795
# Epoch 13/25
# 9/9 [==============================] - 7s 742ms/step - loss: 0.5446 - accuracy: 0.6989 - val_loss: 0.8918 - val_accuracy: 0.6023
# Epoch 14/25
# 9/9 [==============================] - 7s 798ms/step - loss: 0.5458 - accuracy: 0.7138 - val_loss: 0.9897 - val_accuracy: 0.5682
# Epoch 15/25
# 9/9 [==============================] - 7s 798ms/step - loss: 0.6237 - accuracy: 0.6617 - val_loss: 0.7164 - val_accuracy: 0.6932
# Epoch 16/25
# 9/9 [==============================] - 7s 707ms/step - loss: 0.5543 - accuracy: 0.6952 - val_loss: 0.9099 - val_accuracy: 0.6136
# Epoch 17/25
# 9/9 [==============================] - 6s 701ms/step - loss: 0.5492 - accuracy: 0.7175 - val_loss: 0.9352 - val_accuracy: 0.5795
# Epoch 18/25
# 9/9 [==============================] - 7s 725ms/step - loss: 0.5510 - accuracy: 0.6989 - val_loss: 0.7425 - val_accuracy: 0.7273
# Epoch 19/25
# 9/9 [==============================] - 7s 722ms/step - loss: 0.5530 - accuracy: 0.7249 - val_loss: 0.8850 - val_accuracy: 0.5000
# Epoch 20/25
# 9/9 [==============================] - 6s 689ms/step - loss: 0.5353 - accuracy: 0.6952 - val_loss: 0.8065 - val_accuracy: 0.6591
# Epoch 21/25
# 9/9 [==============================] - 7s 689ms/step - loss: 0.5119 - accuracy: 0.7398 - val_loss: 0.9835 - val_accuracy: 0.6250
# Epoch 22/25
# 9/9 [==============================] - 7s 774ms/step - loss: 0.5227 - accuracy: 0.7472 - val_loss: 0.9308 - val_accuracy: 0.6591
# Epoch 23/25
# 9/9 [==============================] - 7s 733ms/step - loss: 0.5138 - accuracy: 0.7658 - val_loss: 0.9522 - val_accuracy: 0.6023
# Epoch 24/25
# 9/9 [==============================] - 7s 706ms/step - loss: 0.5085 - accuracy: 0.7398 - val_loss: 0.9326 - val_accuracy: 0.6364
# Epoch 25/25
# 9/9 [==============================] - 7s 764ms/step - loss: 0.5088 - accuracy: 0.7658 - val_loss: 1.0292 - val_accuracy: 0.6136
# Model saved successfully!
